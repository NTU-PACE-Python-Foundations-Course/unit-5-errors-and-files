# %% [markdown]
# # Unit 5: Robust Code — Errors & Files — Exercises
#
# > **Python Fundamentals** | NTU Academy for Professional and Continuing Education
#
# Complete the reading materials, curated videos, and `notebook.ipynb` before working through these exercises.

# %% [markdown]
# ## Learning objectives
#
# By the end of this unit you will be able to:
#
# - Use try/except to handle errors without crashing
# - Read a CSV file into a list of dictionaries using csv.DictReader
# - Write a complete data pipeline: read, process, flag, report

# %% [markdown]
# ## Exercise 1: Safe type conversion
#
# `ages_raw` is a list of strings, some of which aren't valid numbers. Loop over it and:
#
# 1. Try to convert each value to an `int`
# 2. If it succeeds, add it to a list called `valid_ages`
# 3. If it fails, add the original string to a list called `invalid_entries`
#
# Print both lists, and the average of `valid_ages`.

# %%
ages_raw = ["25", "31", "twenty", "19", "", "45"]

valid_ages = []
invalid_entries = []

# TODO: loop over ages_raw, try int(), sort into the two lists


# TODO: print valid_ages, invalid_entries, and the average of valid_ages

# %% [markdown]
# ## Exercise 2: Reading and writing a text file
#
# 1. Write `shopping_list` to a file called `shopping.txt`, one item per line
# 2. Read the file back
# 3. Print each item with a number prefix, e.g. `1. Milk`

# %%
shopping_list = ["Milk", "Eggs", "Bread", "Coffee"]

# TODO: 1. write shopping_list to shopping.txt, one item per line


# TODO: 2. read shopping.txt back into a list of lines


# TODO: 3. print each item with a number prefix (1. Milk, 2. Eggs, ...)

# %% [markdown]
# ## Exercise 3: Reading a CSV and calculating an average
#
# The code below writes a small CSV file of student grades. Read it back with `csv.DictReader`, convert each `grade` to an `int`, and print the class average (rounded to 1 decimal place).

# %%
import csv

csv_text = """name,grade
Alice,82
Bob,67
Carol,91
Dan,45
Eve,73
"""

with open("grades.csv", "w") as f:
    f.write(csv_text)

# TODO: read grades.csv with csv.DictReader, convert grade to int,
# and print the class average

# %% [markdown]
# ## Exercise 4: Full pipeline — flag and report
#
# Extend Exercise 3's `grades.csv`. Build a pipeline that:
#
# 1. Reads `grades.csv` with `csv.DictReader`
# 2. For each student, sets `status` to `"needs support"` if `grade < 50`, otherwise `"pass"`
# 3. Writes a new file `grade_report.csv` with columns `name`, `grade`, `status`
# 4. Prints how many students need support

# %%
import csv

# TODO: 1. read grades.csv


# TODO: 2. build a list of dicts with name, grade, status


# TODO: 3. write grade_report.csv with columns name, grade, status


# TODO: 4. print how many students need support

# %% [markdown]
# ## Done?
#
# Compare your approach with `solutions.ipynb` once you've had a go yourself — your solution doesn't need to match exactly, as long as it produces the same results.
